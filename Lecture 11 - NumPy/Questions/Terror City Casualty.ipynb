# %% [markdown]
# # Problem statement
# Given file "terrorismData.csv"
#
# It is an open-source database including information on terrorist attacks around the world from 1970 through 2017. This dataset includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period
#
# ## Problem Statement :
# Find top 5 Indian Cities which has most number of casualties ?
#
# Print top 5 cities along with total casualties in that city. Print count of Casualty as integer value.
#
# Note: Ignoring the City which is Unknown.
#
# Casualty = Killed + Wounded.
#
# ## Output Format :
# city_1 casualty_1
#
# city_2 casualty_2
#
# city_3 casualty_3
#
# city_4 casualty_4
#
# city_5 casualty_5

# %%
import os
os.path.abspath(">")
# Out:
# '/Users/manshusharma/Documents/Personal/Data-Science-Machine-Learning/Lecture 11 - NumPy/Questions/>'

# %%
import pandas as pd
data = pd.read_csv("/Users/manshusharma/Documents/Personal/Data-Science-Machine-Learning/Datasets/terrorismData.csv")

# %%
data.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
data["Killed"].fillna(0,inplace=True)
data["Wounded"].fillna(0,inplace=True)
data["Casualty"] = data["Killed"]+data["Wounded"]
newData = data.loc[(data["Country"]=="India") &  (data["City"]!="Unknown")]

# %%
newData
# Out:
#         Year  Month  Day Country              State      Region  \
# 1186    1972      2   22   India              Delhi  South Asia
# 2764    1975      1    2   India              Bihar  South Asia
# 3857    1976      5   26   India              Delhi  South Asia
# 5327    1977      9   28   India        Maharashtra  South Asia
# 7342    1979      1   14   India            Manipur  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 1186        New Delhi  28.585836  77.153336                       Hijacking
# ...

# %%
groupbycities = newData.groupby("City").sum('Casualty').reset_index() # city can be same with diffrent time
groupbycities_sorted = groupbycities.sort_values(by="Casualty",ascending=False)

# %%
groupbycities_sorted.head(5)
# Out:
#            City     Year  Month    Day      Latitude     Longitude  Killed  \
# 4279   Srinagar  1315414   4178  10432  22416.198229  49221.782379   769.0
# 3312  New Delhi   313040   1037   2719   4488.077439  12113.238141   378.0
# 3120     Mumbai    56115    193    551    533.678230   2040.376255   474.0
# 1844      Jammu   113874    360   1001   1865.238291   4266.960549   267.0
# 1607   Guwahati   154367    451   1161   2013.534138   7065.822687   159.0
#
#       Wounded  Casualty
# 4279   2365.0    3134.0
# 3312   1717.0    2095.0
# 3120   1542.0    2016.0
# 1844    852.0    1119.0
# 1607    663.0     822.0

# %%
for index, row in groupbycities_sorted.head(5).iterrows():
    print(row['City'],int(row['Casualty']))
# Out:
# Srinagar 3134
# New Delhi 2095
# Mumbai 2016
# Jammu 1119
# Guwahati 822
